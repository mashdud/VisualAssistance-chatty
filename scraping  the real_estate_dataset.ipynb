# %%
import requests
import pandas as pd
import sqlalchemy

# %%
cookies = {
    'visid_incap_2269415': 'x922V6JDSIKjUtwXtVAi9zLGpmUAAAAAQUIPAAAAAACyBH61jgRbhF51slx32DyJ',
    'incap_ses_304_2269415': 'DaF2a6kzxDDW4DGbIgc4BDXGpmUAAAAAp77dLCwna5bFOo+Jjwnaow==',
    'incap_ses_189_2269415': 'u6QJNLZX5zxR+hX7K3efAjbGpmUAAAAAhZDyVYnQh4Gcul24vmujbA==',
    '_gcl_au': '1.1.1100791278.1705428536',
    '_gid': 'GA1.2.875714738.1705428536',
    'reese84': '3:zZw9teSLHkM9yTHXFSs/uw==:...:vNUiQMPpL8PhBKufex/91aPCVin+fDz51Eyzu4eB2Qg=',
    'gig_bootstrap_3_mrQiIl6ov44s2X3j6NGWVZ9SDDtplqV7WgdcyEpGYnYxl7ygDWPQHqQqtpSiUfko': 'gigya-pr_ver4',
    'visid_incap_2271082': 'OJD+zBatSIiVmyiE814f8GLGpmUAAAAAQUIPAAAAAAAy/zwY0G5V4pzi1pdCx5io',
    'nlbi_2271082': 'zi8xTWSYO36D/bHfVPrQ3QAAAAD3K8OyPWMds18xwX1xOoVA',
    'incap_ses_189_2271082': 'hDMZJ4RbDDLpXBb7K3efAmLGpmUAAAAAa5Z1rS644yfbxp2x625EWA==',
    '_ga': 'GA1.2.74539399.1705428536',
    '_ga_Y07J3B53QP': 'GS1.1.1705428536.1.1.1705428647.11.0.0',
}

headers = {
    'authority': 'api2.realtor.ca',
    'accept': '*/*',
    'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
    'content-type': 'application/x-www-form-urlencoded; charset=UTF-8',
    # 'cookie': 'visid_incap_2269415=x922V6JDSIKjUtwXtVAi9zLGpmUAAAAAQUIPAAAAAACyBH61jgRbhF51slx32DyJ; incap_ses_304_2269415=DaF2a6kzxDDW4DGbIgc4BDXGpmUAAAAAp77dLCwna5bFOo+Jjwnaow==; incap_ses_189_2269415=u6QJNLZX5zxR+hX7K3efAjbGpmUAAAAAhZDyVYnQh4Gcul24vmujbA==; _gcl_au=1.1.1100791278.1705428536; _gid=GA1.2.875714738.1705428536; reese84=3:zZw9teSLHkM9yTHXFSs/uw==:...:vNUiQMPpL8PhBKufex/91aPCVin+fDz51Eyzu4eB2Qg=; gig_bootstrap_3_mrQiIl6ov44s2X3j6NGWVZ9SDDtplqV7WgdcyEpGYnYxl7ygDWPQHqQqtpSiUfko=gigya-pr_ver4; visid_incap_2271082=OJD+zBatSIiVmyiE814f8GLGpmUAAAAAQUIPAAAAAAAy/zwY0G5V4pzi1pdCx5io; nlbi_2271082=zi8xTWSYO36D/bHfVPrQ3QAAAAD3K8OyPWMds18xwX1xOoVA; incap_ses_189_2271082=hDMZJ4RbDDLpXBb7K3efAmLGpmUAAAAAa5Z1rS644yfbxp2x625EWA==; _ga=GA1.2.74539399.1705428536; _ga_Y07J3B53QP=GS1.1.1705428536.1.1.1705428647.11.0.0',
    'origin': 'https://www.realtor.ca',
    'referer': 'https://www.realtor.ca/',
    'sec-ch-ua': '"Not_A Brand";v="8", "Chromium";v="120", "Google Chrome";v="120"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
}

data = {
    'ZoomLevel': '13',
    'LatitudeMax': '43.23227',
    'LongitudeMax': '-80.30442',
    'LatitudeMin': '43.15806',
    'LongitudeMin': '-80.46595',
    'Sort': '6-D',
    'PropertyTypeGroupID': '1',
    'TransactionTypeId': '2',
    'PropertySearchTypeId': '0',
    'Currency': 'CAD',
    'RecordsPerPage': '12',
    'ApplicationId': '1',
    'CultureId': '1',
    'Version': '7.0',
    'CurrentPage': '1',
}

response = requests.post('https://api2.realtor.ca/Listing.svc/PropertySearch_Post', cookies=cookies, headers=headers, data=data)

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'ErrorCode': {'Id': 200,
#   'Description': 'Success - OK',
#   'Status': 'Pins-Via-Cache:false;Sidebar-Items-Via-Cache:0;',
#   'ProductName': 'Realtor API 7 | 20231204.5 | 7b93a9b6276102dde14ac35eb8832a6412823350 | Monday, December 4, 2023 1:46:32 PM',
#   'Version': '1.0.8738.33809'},
#  'Paging': {'RecordsPerPage': 12,
#   'CurrentPage': 1,
#   'TotalRecords': 158,
#   'MaxRecords': 600,
#   'TotalPages': 14,
#   'RecordsShowing': 158,
#   'Pins': 158},
#  'Results': [{'Id': '26419957',
#    'MlsNumber': '40529960',
# ...

# %%
result_json=response.json()

# %%
result_json.keys()
# Out:
# dict_keys(['ErrorCode', 'Paging', 'Results', 'Pins', 'GroupingLevel'])

# %%
result_json['Results']
# Out:
# [{'Id': '26419957',
#   'MlsNumber': '40529960',
# ...

# %%
results_items=result_json['Results']

# %%
len(results_items)
# Out:
# 12

# %%
#address
results_items[0]['Property']['Address']['AddressText']
# Out:
# '1 TOM BROWN Drive Unit# EXP-T020|Paris, Ontario N3L0K3'

# %%
results_items[0]['Building']['Bedrooms']
# Out:
# '3 + 0'

# %%
#
results_items[0]['Building']['BathroomTotal']
# Out:
# '3'

# %%
#agent name
results_items[0]['Individual'][0]['Name']
# Out:
# 'Derek Castro'

# %%
#areacode
results_items[0]['Individual'][0]['Phones'][0]['AreaCode']
# Out:
# '519'

# %%
results_items[0]['Individual'][0]['Phones'][0]['PhoneNumber']
# Out:
# '400-8177'

# %%
#price
results_items[0]['Property']['Price']
# Out:
# '$657,400'

# %%
address=[]
bedrooms=[]
bathrooms=[]
Agent_Name=[]
Area_code=[]
phone_number=[]
price=[]

for results in results_items:
    
    try:
        address.append(results['Property']['Address']['AddressText'])
    
    except:
        address.append('')
        
        
    try:
        bedrooms.append(results['Building']['Bedrooms'])
                    
    except:
        bedrooms.append('')
                        
    try:
    
        bathrooms.append(results['Building']['BathroomTotal'])
                         
    except:
        
         bathrooms.append('')   
                         
    try:
         Agent_Name.append(results['Individual'][0]['Name'])
    except:
         Agent_Name.append('')
                         
    try:
        Area_code.append(results['Individual'][0]['Phones'][0]['AreaCode'])
    except:
         Area_code.append('')
                         
    try:
        phone_number.append(results['Individual'][0]['Phones'][0]['PhoneNumber'])
    except:
         phone_number.append('')
                            
    try:
        price.append(results['Property']['Price'])
    except:
        price.append('')

# %%
address
# Out:
# ['1 TOM BROWN Drive Unit# EXP-T020|Paris, Ontario N3L0K3',
#  '54 DRAKE AVE|Brant, Ontario N3L0J1',
#  '14 AMELIA Street|Paris, Ontario N3L1Z3',
#  '670 BISHOPSGATE RD|Brant, Ontario N3L3E3',
#  '670 BISHOPSGATE Road Unit# 9|Paris, Ontario N3L3E3',
#  '35 GEORGE BRIER DR W|Brant, Ontario N3L3Z9',
#  '3 MCGOVERN LANE|Brant, Ontario N3L0K3',
#  '3 MCGOVERN Lane|Paris, Ontario N3L0K3',
#  '11 WHITTON DR|Brant, Ontario N3L0L1',
#  '148 FLAGG Avenue|Paris, Ontario N3L0K5',
#  '113 HARTLEY Avenue Unit# 35|Paris, Ontario N3L0K8',
#  '14 QUEEN Street|Paris, Ontario N3L1C1']

# %%
df_results=pd.DataFrame({'Address':address,'Bedrooms':bedrooms , 'Bathrooms': bathrooms,'Agent_Name' :Agent_Name,'Area_code':Area_code,'Phone_number':phone_number,'Price': price})

# %%
df_results
# Out:
#                                               Address Bedrooms Bathrooms  \
# 0   1 TOM BROWN Drive Unit# EXP-T020|Paris, Ontari...    3 + 0         3
# 1                  54 DRAKE AVE|Brant, Ontario N3L0J1        4         4
# 2              14 AMELIA Street|Paris, Ontario N3L1Z3    2 + 1         2
# 3            670 BISHOPSGATE RD|Brant, Ontario N3L3E3        4         3
# 4   670 BISHOPSGATE Road Unit# 9|Paris, Ontario N3...    4 + 0         3
# 5          35 GEORGE BRIER DR W|Brant, Ontario N3L3Z9        3         3
# 6               3 MCGOVERN LANE|Brant, Ontario N3L0K3        4         3
# 7               3 MCGOVERN Lane|Paris, Ontario N3L0K3    2 + 2         3
# 8                 11 WHITTON DR|Brant, Ontario N3L0L1        4         3
# 9              148 FLAGG Avenue|Paris, Ontario N3L0K5    3 + 0         3
# 10  113 HARTLEY Avenue Unit# 35|Paris, Ontario N3L0K8    2 + 0         3
# 11              14 QUEEN Street|Paris, Ontario N3L1C1    5 + 0         2
#
# ...

# %%
from sqlalchemy import create_engine
import psycopg2
db_host = "localhost"
db_name = "postgres"
db_pass = "4895"
db_user = "postgres"

engine = create_engine(f"postgresql://{db_user}:{db_pass}@{db_host}/{db_name}")

# %%
df_results.to_sql('real_estate_results',engine)
# Out:
# 12

# %%
#create sqlalchemy engine
# Out:
#                                               Address Bedrooms Bathrooms  \
# 0   1 TOM BROWN Drive Unit# EXP-T020|Paris, Ontari...    3 + 0         3
# 1                  54 DRAKE AVE|Brant, Ontario N3L0J1        4         4
# 2              14 AMELIA Street|Paris, Ontario N3L1Z3    2 + 1         2
# 3            670 BISHOPSGATE RD|Brant, Ontario N3L3E3        4         3
# 4   670 BISHOPSGATE Road Unit# 9|Paris, Ontario N3...    4 + 0         3
# 5          35 GEORGE BRIER DR W|Brant, Ontario N3L3Z9        3         3
# 6               3 MCGOVERN LANE|Brant, Ontario N3L0K3        4         3
# 7               3 MCGOVERN Lane|Paris, Ontario N3L0K3    2 + 2         3
# 8                 11 WHITTON DR|Brant, Ontario N3L0L1        4         3
# 9              148 FLAGG Avenue|Paris, Ontario N3L0K5    3 + 0         3
# 10  113 HARTLEY Avenue Unit# 35|Paris, Ontario N3L0K8    2 + 0         3
# 11              14 QUEEN Street|Paris, Ontario N3L1C1    5 + 0         2
#
# ...

# %%
import requests

address = []
bedrooms = []
bathrooms = []
Agent_Name = []
Area_code = []
phone_number = []
price = []

for i in range(1, 20):
    headers = {
        
    'authority': 'api2.realtor.ca',
    'accept': '*/*',
    'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
    'content-type': 'application/x-www-form-urlencoded; charset=UTF-8',
    # 'cookie': 'visid_incap_2269415=x922V6JDSIKjUtwXtVAi9zLGpmUAAAAAQUIPAAAAAACyBH61jgRbhF51slx32DyJ; incap_ses_304_2269415=DaF2a6kzxDDW4DGbIgc4BDXGpmUAAAAAp77dLCwna5bFOo+Jjwnaow==; incap_ses_189_2269415=u6QJNLZX5zxR+hX7K3efAjbGpmUAAAAAhZDyVYnQh4Gcul24vmujbA==; _gcl_au=1.1.1100791278.1705428536; _gid=GA1.2.875714738.1705428536; reese84=3:zZw9teSLHkM9yTHXFSs/uw==:...:vNUiQMPpL8PhBKufex/91aPCVin+fDz51Eyzu4eB2Qg=; gig_bootstrap_3_mrQiIl6ov44s2X3j6NGWVZ9SDDtplqV7WgdcyEpGYnYxl7ygDWPQHqQqtpSiUfko=gigya-pr_ver4; visid_incap_2271082=OJD+zBatSIiVmyiE814f8GLGpmUAAAAAQUIPAAAAAAAy/zwY0G5V4pzi1pdCx5io; nlbi_2271082=zi8xTWSYO36D/bHfVPrQ3QAAAAD3K8OyPWMds18xwX1xOoVA; incap_ses_189_2271082=hDMZJ4RbDDLpXBb7K3efAmLGpmUAAAAAa5Z1rS644yfbxp2x625EWA==; _ga=GA1.2.74539399.1705428536; _ga_Y07J3B53QP=GS1.1.1705428536.1.1.1705428647.11.0.0',
    'origin': 'https://www.realtor.ca',
    'referer': 'https://www.realtor.ca/',
    'sec-ch-ua': '"Not_A Brand";v="8", "Chromium";v="120", "Google Chrome";v="120"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',

       
    }

    data = {
        'ZoomLevel': '13',
        'LatitudeMax': '43.23227',
        'LongitudeMax': '-80.30442',
        'LatitudeMin': '43.15806',
        'LongitudeMin': '-80.46595',
        'Sort': '6-D',
        'PropertyTypeGroupID': '1',
        'TransactionTypeId': '2',
        'PropertySearchTypeId': '0',
        'Currency': 'CAD',
        'RecordsPerPage': '12',
        'ApplicationId': '1',
        'CultureId': '1',
        'Version': '7.0',
        'CurrentPage':str(i),
    }

    response = requests.post('https://api2.realtor.ca/Listing.svc/PropertySearch_Post', headers=headers, data=data)
    if response.status_code == 200 and 'application/json' in response.headers.get('Content-Type', ''):
        try:
            results_json = response.json()
            # Process results_json...
        except json.JSONDecodeError:
            print("Failed to decode JSON.")
            print("Response Text:", response.text)
    else:
        print("Request failed or returned non-JSON content.")
        print("Status Code:", response.status_code)
        print("Response Headers:", response.headers)
        print("Response Text:", response.text)
    
    results_json=response.json()
    results_items=result_json['Results']
    
    
    
    results_json = response.json()
    results_items = results_json['Results']

    for result in results_items:
        try:
            address.append(result['Property']['Address']['AddressText'])
        except:
            address.append('')

        try:
            bedrooms.append(result['Building']['Bedrooms'])
        except:
            bedrooms.append('')

        try:
            bathrooms.append(result['Building']['BathroomTotal'])
        except:
            bathrooms.append('')

        try:
            Agent_Name.append(result['Individual'][0]['Name'])
        except:
            Agent_Name.append('')

        try:
            Area_code.append(result['Individual'][0]['Phones'][0]['AreaCode'])
        except:
            Area_code.append('')

        try:
            phone_number.append(result['Individual'][0]['Phones'][0]['PhoneNumber'])
        except:
            phone_number.append('')

        try:
            price.append(result['Property']['Price'])
        except:
            price.append('')
